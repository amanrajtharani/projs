# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
salary_data = pd.read_csv('ds_salaries.csv')

# %%
salary_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 220.1+ KB

# %%
salary_data.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
def categorize_salary(salary):
    if salary > 100000:
        return "High income"
    elif salary == 100000:
        return "Medium income"
    else:
        return "Low income"

salary_data["sal>100000"] = salary_data["salary"].map(categorize_salary)


salary_data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
plt.figure(figsize=(20,10))
graph = sns.countplot(x="job_title",data=salary_data,hue="sal>100000")
plt.title("Salaries by Job Title and Salary Greater than 100000")
plt.show()

# %%
get_col = pd.read_csv('ds_salaries.csv',usecols=["job_title"])
#or we can use uecols = [1,3]
get_col.head()
# Out:
#                   job_title
# 0  Principal Data Scientist
# 1               ML Engineer
# 2               ML Engineer
# 3            Data Scientist
# 4            Data Scientist

# %%
row_inp = int(input("Enter the number of rows which you want to get : "))
get_row = pd.read_csv('ds_salaries.csv',nrows=row_inp)
get_row
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
# 5       2023               SE              FT         Applied Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
# ...

# %%
get_col = pd.read_csv('ds_salaries.csv',header=1)
get_col
# Out:
#       2023  SE  FT  Principal Data Scientist    80000  EUR   85847  ES  100  \
# 0     2023  MI  CT               ML Engineer    30000  USD   30000  US  100
# 1     2023  MI  CT               ML Engineer    25500  USD   25500  US  100
# 2     2023  SE  FT            Data Scientist   175000  USD  175000  CA  100
# 3     2023  SE  FT            Data Scientist   120000  USD  120000  CA  100
# 4     2023  SE  FT         Applied Scientist   222200  USD  222200  US    0
# ...    ...  ..  ..                       ...      ...  ...     ...  ..  ...
# 3749  2020  SE  FT            Data Scientist   412000  USD  412000  US  100
# 3750  2021  MI  FT  Principal Data Scientist   151000  USD  151000  US  100
# 3751  2020  EN  FT            Data Scientist   105000  USD  105000  US  100
# 3752  2020  EN  CT     Business Data Analyst   100000  USD  100000  US  100
# 3753  2021  SE  FT      Data Science Manager  7000000  INR   94665  IN   50
#
#      ES.1  L
# 0      US  S
# 1      US  S
# ...

# %%
get_col = pd.read_csv('ds_salaries.csv',names=["year","level"])
get_col
# Out:
#                                                                                                                                                        year  \
# work_year experience_level employment_type job_title                salary  salary_currency salary_in_usd employee_residence remote_ratio  company_location
# 2023      SE               FT              Principal Data Scientist 80000   EUR             85847         ES                 100                         ES
#           MI               CT              ML Engineer              30000   USD             30000         US                 100                         US
#                                                                     25500   USD             25500         US                 100                         US
#           SE               FT              Data Scientist           175000  USD             175000        CA                 100                         CA
# ...

# %%
gr = salary_data.groupby(['job_title','salary'])
salary_data.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size   sal>100000
# ...

# %%
salary_data.groupby('remote_ratio').size()
# Out:
# remote_ratio
# 0      1923
# 50      189
# 100    1643
# dtype: int64

# %%
salary_data.work_year
# Out:
# 0       2023
# 1       2023
# 2       2023
# 3       2023
# 4       2023
#         ...
# 3750    2020
# 3751    2021
# 3752    2020
# 3753    2020
# 3754    2021
# Name: work_year, Length: 3755, dtype: int64

# %%
salary_data.drop_duplicates()
salary_data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
salary_data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
salary_data.experience_level[0]
# Out:
# 'SE'

# %%
salary_data.iloc[0]
# Out:
# work_year                                 2023
# experience_level                            SE
# employment_type                             FT
# job_title             Principal Data Scientist
# salary                                   80000
# salary_currency                            EUR
# salary_in_usd                            85847
# employee_residence                          ES
# remote_ratio                               100
# company_location                            ES
# company_size                                 L
# sal>100000                          Low income
# Name: 0, dtype: object

# %%
salary_data.iloc[0,3]
# Out:
# 'Principal Data Scientist'

# %%
salary_data.iloc[:,0]
# Out:
# 0       2023
# 1       2023
# 2       2023
# 3       2023
# 4       2023
#         ...
# 3750    2020
# 3751    2021
# 3752    2020
# 3753    2020
# 3754    2021
# Name: work_year, Length: 3755, dtype: int64

# %%
loc = salary_data.iloc[:5, 1].index=['a','b','c','d','e']
loc
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
salary_data.iloc[[0, 1, 5], 2]
# Out:
# 0    FT
# 1    CT
# 5    FT
# Name: employment_type, dtype: object

# %%
salary_data.iloc[-5:]
# Out:
#       work_year experience_level employment_type                 job_title  \
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
# ...

# %%
salary_data.loc[0, 'employment_type']
# Out:
# 'FT'

# %%
salary_data.loc[salary_data.work_year == '2021']
salary_data.work_year
# Out:
# 0       2023
# 1       2023
# 2       2023
# 3       2023
# 4       2023
#         ...
# 3750    2020
# 3751    2021
# 3752    2020
# 3753    2020
# 3754    2021
# Name: work_year, Length: 3755, dtype: int64

# %%
salary_data.loc[salary_data.experience_level.isin(['SE', 'MI'])]
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3748       2021               MI              FT             Data Engineer
# 3749       2021               SE              FT           Data Specialist
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
salary_data.rename(columns={'work_year': 'year'})
# Out:
#       year experience_level employment_type                 job_title  \
# 0     2023               SE              FT  Principal Data Scientist
# 1     2023               MI              CT               ML Engineer
# 2     2023               MI              CT               ML Engineer
# 3     2023               SE              FT            Data Scientist
# 4     2023               SE              FT            Data Scientist
# ...    ...              ...             ...                       ...
# 3750  2020               SE              FT            Data Scientist
# 3751  2021               MI              FT  Principal Data Scientist
# 3752  2020               EN              FT            Data Scientist
# 3753  2020               EN              CT     Business Data Analyst
# 3754  2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
#canadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")
#british_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")

#pd.concat([canadian_youtube, british_youtube])
